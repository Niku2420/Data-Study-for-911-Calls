# %%
#check for datafile 
import os

# %%
print(os.listdir())
# Out:
# ['911.csv', 'projectOne.ipynb', '.ipynb_checkpoints']

# %%
# impoting all the libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#using of inline function 
# %matplotlib inline

# %%
# loading of the data
dataFrame=pd.read_csv('911.csv')

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289240 entries, 0 to 289239
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        289240 non-null  float64
#  1   lng        289240 non-null  float64
#  2   desc       289240 non-null  object
#  3   zip        253942 non-null  float64
#  4   title      289240 non-null  object
#  5   timeStamp  289240 non-null  object
#  6   twp        289137 non-null  object
#  7   addr       289240 non-null  object
#  8   e          289240 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 19.9+ MB

# %%
dataFrame
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 289235  40.024967 -75.282905
# 289236  40.024967 -75.282905
# 289237  40.107918 -75.163347
# 289238  40.061922 -75.117655
# 289239  40.098662 -75.352777
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 289235  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# ...

# %%
dataFrame.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289240 entries, 0 to 289239
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   lat        289240 non-null  float64
#  1   lng        289240 non-null  float64
#  2   desc       289240 non-null  object
#  3   zip        253942 non-null  float64
#  4   title      289240 non-null  object
#  5   timeStamp  289240 non-null  object
#  6   twp        289137 non-null  object
#  7   addr       289240 non-null  object
#  8   e          289240 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 19.9+ MB

# %%
#top5 zip codes 
dataFrame['zip'].value_counts()
# Out:
# 19401.0    19821
# 19464.0    19276
# 19403.0    14524
# 19446.0    13939
# 19406.0     9601
#            ...
# 77316.0        1
# 19382.0        1
# 19457.0        1
# 19486.0        1
# 17555.0        1
# Name: zip, Length: 125, dtype: int64

# %%
dataFrame['zip'].value_counts().head(5)
# Out:
# 19401.0    19821
# 19464.0    19276
# 19403.0    14524
# 19446.0    13939
# 19406.0     9601
# Name: zip, dtype: int64

# %%
#top6 township reaching to 911
dataFrame['twp'].value_counts().head(6)
# Out:
# LOWER MERION    24826
# ABINGTON        17820
# NORRISTOWN      16546
# UPPER MERION    15288
# CHELTENHAM      13359
# POTTSTOWN       12039
# Name: twp, dtype: int64

# %%
#unique reasons to call 911
dataFrame['title'].nunique()
# Out:
# 131

# %%
# .apply i have to study on my own by using pandas documentaions for the assignment.

# %%
dataFrame['SpecificReasons']=dataFrame['title'].apply(lambda title: title.split(':')[1])

# %%
dataFrame
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 289235  40.024967 -75.282905
# 289236  40.024967 -75.282905
# 289237  40.107918 -75.163347
# 289238  40.061922 -75.117655
# 289239  40.098662 -75.352777
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 289235  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# ...

# %%
dataFrame['SpecificReasons'].value_counts().head(10)
# Out:
#  VEHICLE ACCIDENT -       68123
#  DISABLED VEHICLE -       20667
#  VEHICLE ACCIDENT         16747
#  FIRE ALARM               16359
#  RESPIRATORY EMERGENCY    14637
#  FALL VICTIM              14584
#  CARDIAC EMERGENCY        14491
#  ROAD OBSTRUCTION -        8767
#  SUBJECT IN PAIN           8151
#  HEAD INJURY               7613
# Name: SpecificReasons, dtype: int64

# %%
dataFrame['BroadReasons']=dataFrame['title'].apply(lambda title: title.split(':')[0] )

# %%
dataFrame.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
dataFrame['BroadReasons'].value_counts().head() #.head() is not compulsary its will show same without that beacause there are only three values and .head() shows 5 values by defauly
# Out:
# EMS        144362
# Traffic    101889
# Fire        42989
# Name: BroadReasons, dtype: int64

# %%
dataFrame
# Out:
#               lat        lng  \
# 0       40.297876 -75.581294
# 1       40.258061 -75.264680
# 2       40.121182 -75.351975
# 3       40.116153 -75.343513
# 4       40.251492 -75.603350
# ...           ...        ...
# 289235  40.024967 -75.282905
# 289236  40.024967 -75.282905
# 289237  40.107918 -75.163347
# 289238  40.061922 -75.117655
# 289239  40.098662 -75.352777
#
#                                                      desc      zip  \
# 0       REINDEER CT & DEAD END;  NEW HANOVER; Station ...  19525.0
# 1       BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  19446.0
# 2       HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  19401.0
# 3       AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  19401.0
# 4       CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...      NaN
# ...                                                   ...      ...
# 289235  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# ...

# %%
sns.countplot(x='BroadReasons',data=dataFrame )
# Out:
# <AxesSubplot:xlabel='BroadReasons', ylabel='count'>

# %%
#now converting of timestamp from string value to to actual timestamp value
dataFrame['timeStamp']=pd.to_datetime(dataFrame['timeStamp'])

# %%
#to check wether the timestamp is changed or not 
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289240 entries, 0 to 289239
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   lat              289240 non-null  float64
#  1   lng              289240 non-null  float64
#  2   desc             289240 non-null  object
#  3   zip              253942 non-null  float64
#  4   title            289240 non-null  object
#  5   timeStamp        289240 non-null  datetime64[ns]
#  6   twp              289137 non-null  object
#  7   addr             289240 non-null  object
#  8   e                289240 non-null  int64
#  9   SpecificReasons  289240 non-null  object
#  10  BroadReasons     289240 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 24.3+ MB

# %%
dataFrame['timeStamp'].head(10)
# Out:
# 0   2015-12-10 17:10:52
# 1   2015-12-10 17:29:21
# 2   2015-12-10 14:39:21
# 3   2015-12-10 16:47:36
# 4   2015-12-10 16:56:52
# 5   2015-12-10 15:39:04
# 6   2015-12-10 16:46:48
# 7   2015-12-10 16:17:05
# 8   2015-12-10 16:51:42
# 9   2015-12-10 17:35:41
# Name: timeStamp, dtype: datetime64[ns]

# %%
type(dataFrame['timeStamp'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
dataFrame['timeStamp'].iloc[0]
# Out:
# Timestamp('2015-12-10 17:10:52')

# %%
# for creating column for hour
dataFrame['Hour']=dataFrame['timeStamp'].apply(lambda time: time.hour)

# %%
dataFrame.head(10)
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5  40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6  40.182111 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7  40.217286 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8  40.289027 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9  40.102398 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
#
#        zip                        title           timeStamp  \
# 0  19525.0       EMS: BACK PAINS/INJURY 2015-12-10 17:10:52
# ...

# %%
# for creating column for months
dataFrame['Months']=dataFrame['timeStamp'].apply(lambda time: time.month)

# %%
dataFrame.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
dataFrame['Day']=dataFrame['timeStamp'].apply(lambda time: time.dayofweek)

# %%
dataFrame.head(20)
# Out:
#           lat        lng                                               desc  \
# 0   40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1   40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2   40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3   40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4   40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
# 5   40.253473 -75.283245  CANNON AVE & W 9TH ST;  LANSDALE; Station 345;...
# 6   40.182111 -75.127795  LAUREL AVE & OAKDALE AVE;  HORSHAM; Station 35...
# 7   40.217286 -75.405182  COLLEGEVILLE RD & LYWISKI RD;  SKIPPACK; Stati...
# 8   40.289027 -75.399590  MAIN ST & OLD SUMNEYTOWN PIKE;  LOWER SALFORD;...
# 9   40.102398 -75.291458  BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...
# 10  40.231990 -75.251891  RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...
# ...

# %%
dataFrame['Day'].unique()# with unique we can count unique values present in big data
# Out:
# array([3, 4, 5, 6, 0, 1, 2])

# %%
dataFrame['Hour'].nunique()
# Out:
# 24

# %%
dataFrame['Months'].nunique()
# Out:
# 12

# %%
sns.countplot(x='Months',data=dataFrame,hue='BroadReasons')
# Out:
# <AxesSubplot:xlabel='Months', ylabel='count'>

# %%
# using of groupby method of seaborn
byMonth=dataFrame.groupby('Months').count()

# %%
byMonth
# Out:
#           lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Months
# 1       24701  24701  24701  21877  24701      24701  24692  24701  24701
# 2       21663  21663  21663  19161  21663      21663  21658  21663  21663
# 3       22743  22743  22743  20160  22743      22743  22732  22743  22743
# 4       22343  22343  22343  19671  22343      22343  22336  22343  22343
# 5       23093  23093  23093  20254  23093      23093  23082  23093  23093
# 6       24065  24065  24065  21070  24065      24065  24058  24065  24065
# 7       23856  23856  23856  20940  23856      23856  23850  23856  23856
# 8       23657  23657  23657  20739  23657      23657  23646  23657  23657
# 9       23001  23001  23001  20014  23001      23001  22993  23001  23001
# 10      24113  24113  24113  20931  24113      24113  24109  24113  24113
# 11      23639  23639  23639  20727  23639      23639  23629  23639  23639
# 12      32366  32366  32366  28398  32366      32366  32352  32366  32366
# ...

# %%
byMonth['twp'].plot() #according to months (survey)
# Out:
# <AxesSubplot:xlabel='Months'>

# %%
byDays=dataFrame.groupby('Day').count()

# %%
byDays
# Out:
#        lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# Day
# 0    42092  42092  42092  37030  42092      42092  42081  42092  42092
# 1    43744  43744  43744  38385  43744      43744  43731  43744  43744
# 2    43442  43442  43442  38327  43442      43442  43422  43442  43442
# 3    42784  42784  42784  37616  42784      42784  42770  42784  42784
# 4    44468  44468  44468  38923  44468      44468  44450  44468  44468
# 5    38637  38637  38637  33777  38637      38637  38623  38637  38637
# 6    34073  34073  34073  29884  34073      34073  34060  34073  34073
#
#      SpecificReasons  BroadReasons   Hour  Months
# Day
# 0              42092         42092  42092   42092
# 1              43744         43744  43744   43744
# 2              43442         43442  43442   43442
# 3              42784         42784  42784   42784
# 4              44468         44468  44468   44468
# 5              38637         38637  38637   38637
# ...

# %%
byDays['twp'].plot()# this is according to days (survey)
# Out:
# <AxesSubplot:xlabel='Day'>
